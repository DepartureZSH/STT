# %% [markdown]
# # STT

# %% [raw]
# ├── data
# │   ├── solutions
# │   │   ├── agh-ggis-spr17
# │   │   │   ├── solution1_agh-fis-spr17.xml
# │   │   │   ├── ...
# │   │   │   └── solution98_agh-fis-spr17.xml
# │   │   ├── ...
# │   │   └── yach-fal17
# │   │       ├── solution1_yach-fal17.xml
# │   │       ├── ...
# │   │       └── solution98_yach-fal17.xml
# │   └── source
# │       ├── early
# │       │   ├── agh-fis-spr17.xml
# │       │   ├── agh-ggis-spr17.xml
# │       │   ├── bet-fal17.xml
# │       │   ├── iku-fal17.xml
# │       │   ├── mary-spr17.xml
# │       │   ├── muni-fi-spr16.xml
# │       │   ├── muni-fsps-spr17.xml
# │       │   ├── muni-pdf-spr16c.xml
# │       │   ├── pu-llr-spr17.xml
# │       │   └── tg-fal17.xml
# │       ├── late
# │       │   ├── README.md
# │       │   ├── agh-fal17.xml
# │       │   ├── bet-spr18.xml
# │       │   ├── iku-spr18.xml
# │       │   ├── lums-fal17.xml
# │       │   ├── mary-fal18.xml
# │       │   ├── muni-fi-fal17.xml
# │       │   ├── muni-fspsx-fal17.xml
# │       │   ├── muni-pdfx-fal17.xml
# │       │   ├── pu-d9-fal19.xml
# │       │   └── tg-spr18.xml
# │       ├── middle
# │       │   ├── agh-ggos-spr17.xml
# │       │   ├── agh-h-spr17.xml
# │       │   ├── lums-spr18.xml
# │       │   ├── muni-fi-spr17.xml
# │       │   ├── muni-fsps-spr17c.xml
# │       │   ├── muni-pdf-spr16.xml
# │       │   ├── nbi-spr18.xml
# │       │   ├── pu-d5-spr17.xml
# │       │   ├── pu-proj-fal19.xml
# │       │   └── yach-fal17.xml
# │       └── test
# │           ├── bet-sum18.xml
# │           ├── lums-sum17.xml
# │           ├── pu-c8-spr07.xml
# │           ├── pu-cs-fal07.xml
# │           ├── pu-llr-spr07.xml
# │           └── wbg-fal10.xml
# ├── main.ipynb
# ├── main.py
# ├── requirements.txt
# └── src
#     ├── __init__.py
#     ├── data
#     │   ├── DataReader.py
#     │   ├── GraphMapping.py
#     │   ├── Segmentation.py
#     │   └── __init__.py
#     ├── optimazier
#     │   ├── GRAPH.py
#     │   ├── MARL.py
#     │   ├── SOTA.py
#     │   └── __init__.py
#     ├── solver
#     │   ├── __init__.py
#     │   ├── gurobi.py
#     │   └── train.py
#     └── utils
#         ├── __init__.py
#         ├── constraints.py
#         ├── dataReader.py
#         ├── solutionReader.py
#         ├── solutionWriter.py
#         └── validator.py

# %% [markdown]
# ![Pipeline](docs/Pipeline.jpg)

# %% [markdown]
# ## DataLoader

# %% [markdown]
# **Step1: Load Instance data**

# %% [markdown]
# **Step2: Large or Small**

# %% [markdown]
# Small Instance: [Small Class Group]
#
# Large Instance: continue

# %% [markdown]
# > **Step2_1: [Large Instance Only] Graph Mapping**

# %% [markdown]
# > **Step2_2: [Large Instance Only] Community Segmentation**
#
# output: [Small Class Group, Small Class Group, ...]

# %% [markdown]
# > **Step2_3: [Large Instance Only] ReLoad Small class groups**

# %% [markdown]
# **Step3: [for each Small Class Groups] Graph Mapping**

# %% [markdown]
# # MIP

# %% [markdown]
# ouput: [valid/invalid solution, ..., valid/invalid solution]

# %% [markdown]
# # Optimizer

# %% [markdown]
# **Step1: Load Solutions**

# %% [markdown]
# ## Step2 [Method A] SOTA Optimizer

# %% [markdown]
# ## Step2 [Method B] MARL Optimizer

# %% [markdown]
# ## Step2 [Method C] Graph Optimizer
